# %%
import numpy as np
import pandas as pd
import seaborn as sns
from pandas import read_csv
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
dataset=pd.read_csv('Obesity.csv')
dataset = dataset.convert_dtypes()
#print(dataset)
#first part of the requirement tasks (Data Analysis task)
#a)Display the first 12 rows of the dataset(Obesity)
print(dataset.head(12))
print("========================================================================================")
#a)Display the last 12 rows of the dataset(Obesity)
print(dataset.tail(12))
print("========================================================================================")
#b)Identify and print the total number of rows and columns present.
print(dataset.shape)
print("========================================================================================")
#c)List all column names along with their corresponding data types
print(dataset.dtypes)
print("========================================================================================")
#d)Print the name of the first column.
print(dataset.columns[0])
print("========================================================================================")
#e) Generate a summary of the dataset, including non-null counts and data types.
print(dataset.info())
print("========================================================================================")
#f) Choose a categorical attribute and display the distinct values it contains.
print(dataset['NObeyesdad'].unique())
print("========================================================================================")
#g) Identify the most frequently occurring value in the chosen categorical attribute.
print(dataset['NObeyesdad'].mode())
print("========================================================================================")
#h) Calculate and present the mean, median, standard deviation, and percentiles (20)
resulth = dataset.describe(percentiles=[0.2])
meanvalues = resulth.loc["mean"]
stdvalues = resulth.loc["std"]
medianvalues = resulth.loc["50%"]
percentile20th = resulth.loc["20%"]
print("Mean:\n", meanvalues)
print("Standard Deviation:\n", stdvalues)
print("Median:\n", medianvalues)
print("20th Percentile:\n", percentile20th)


print("========================================================================================")
# Out:
#     Gender  Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0   Female   21    1.62    64.0                            yes   no   2.0
# 1   Female   21    1.52    56.0                            yes   no   3.0
# 2     Male   23     1.8    77.0                            yes   no   2.0
# 3     Male   27     1.8    87.0                             no   no   3.0
# 4     Male   22    1.78    89.8                             no   no   2.0
# 5     Male   29    1.62    53.0                             no  yes   2.0
# 6   Female   23     1.5    55.0                            yes  yes   3.0
# 7     Male   22    1.64    53.0                             no   no   2.0
# 8     Male   24    1.78    64.0                            yes  yes   3.0
# 9     Male   22    1.72    68.0                            yes  yes   2.0
# 10    Male   26    1.85   105.0                            yes  yes   3.0
# 11  Female   21    1.72    80.0                            yes  yes   2.0
#
#     NCP        CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0   3.0   Sometimes    no   2.0   no  0.0  1.0          no
# 1   3.0   Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2   3.0   Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3   3.0   Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4   1.0   Sometimes    no   2.0   no  0.0  0.0   Sometimes
# 5   3.0   Sometimes    no   2.0   no  0.0  0.0   Sometimes
# 6   3.0   Sometimes    no   2.0   no  1.0  0.0   Sometimes
# 7   3.0   Sometimes    no   2.0   no  3.0  0.0   Sometimes
# 8   3.0   Sometimes    no   2.0   no  1.0  1.0  Frequently
# 9   3.0   Sometimes    no   2.0   no  1.0  1.0          no
# 10  3.0  Frequently    no   3.0   no  2.0  2.0   Sometimes
# 11  3.0  Frequently    no   2.0  yes  2.0  1.0   Sometimes
#
#                    MTRANS           NObeyesdad
# 0   Public_Transportation        Normal_Weight
# 1   Public_Transportation        Normal_Weight
# 2   Public_Transportation        Normal_Weight
# 3                 Walking   Overweight_Level_I
# 4   Public_Transportation  Overweight_Level_II
# 5              Automobile        Normal_Weight
# 6               Motorbike        Normal_Weight
# 7   Public_Transportation        Normal_Weight
# 8   Public_Transportation        Normal_Weight
# 9   Public_Transportation        Normal_Weight
# 10  Public_Transportation       Obesity_Type_I
# 11  Public_Transportation  Overweight_Level_II
# ========================================================================================
#       Gender  Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 2099  Female   26    1.63  108.09                            yes  yes   3.0
# 2100  Female   26    1.63  107.38                            yes  yes   3.0
# 2101  Female   26    1.63  107.22                            yes  yes   3.0
# 2102  Female   26    1.63  108.11                            yes  yes   3.0
# 2103  Female   21    1.72  133.03                            yes  yes   3.0
# 2104  Female   22    1.73  133.04                            yes  yes   3.0
# 2105  Female   21    1.73  131.34                            yes  yes   3.0
# 2106  Female   21    1.71  131.41                            yes  yes   3.0
# 2107  Female   22    1.75  133.74                            yes  yes   3.0
# 2108  Female   23    1.75  133.69                            yes  yes   3.0
# 2109  Female   24    1.74  133.35                            yes  yes   3.0
# 2110  Female   24    1.74  133.47                            yes  yes   3.0
#
#       NCP       CAEC SMOKE  CH2O SCC   FAF    TUE       CALC  \
# 2099  3.0  Sometimes    no  1.76  no  0.09  0.465  Sometimes
# 2100  3.0  Sometimes    no  2.51  no  0.03  0.484  Sometimes
# 2101  3.0  Sometimes    no  2.49  no  0.07  0.456  Sometimes
# 2102  3.0  Sometimes    no  2.32  no  0.05  0.413  Sometimes
# 2103  3.0  Sometimes    no  1.65  no  1.54  0.912  Sometimes
# 2104  3.0  Sometimes    no  1.61  no  1.51  0.931  Sometimes
# 2105  3.0  Sometimes    no   1.8  no  1.73  0.898  Sometimes
# 2106  3.0  Sometimes    no  1.73  no  1.68  0.906  Sometimes
# 2107  3.0  Sometimes    no  2.01  no  1.34  0.599  Sometimes
# 2108  3.0  Sometimes    no  2.05  no  1.41  0.646  Sometimes
# 2109  3.0  Sometimes    no  2.85  no  1.14  0.586  Sometimes
# 2110  3.0  Sometimes    no  2.86  no  1.03  0.714  Sometimes
#
#                      MTRANS        NObeyesdad
# 2099  Public_Transportation  Obesity_Type_III
# 2100  Public_Transportation  Obesity_Type_III
# 2101  Public_Transportation  Obesity_Type_III
# 2102  Public_Transportation  Obesity_Type_III
# 2103  Public_Transportation  Obesity_Type_III
# 2104  Public_Transportation  Obesity_Type_III
# 2105  Public_Transportation  Obesity_Type_III
# 2106  Public_Transportation  Obesity_Type_III
# 2107  Public_Transportation  Obesity_Type_III
# 2108  Public_Transportation  Obesity_Type_III
# 2109  Public_Transportation  Obesity_Type_III
# 2110  Public_Transportation  Obesity_Type_III
# ========================================================================================
# (2111, 17)
# ========================================================================================
# Gender                            string[python]
# Age                                        Int64
# Height                                   Float64
# Weight                                   Float64
# family_history_with_overweight    string[python]
# FAVC                              string[python]
# FCVC                                     Float64
# NCP                                      Float64
# CAEC                              string[python]
# SMOKE                             string[python]
# CH2O                                     Float64
# SCC                               string[python]
# FAF                                      Float64
# TUE                                      Float64
# CALC                              string[python]
# MTRANS                            string[python]
# NObeyesdad                        string[python]
# dtype: object
# ========================================================================================
# Gender
# ========================================================================================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   string
#  1   Age                             2111 non-null   Int64
#  2   Height                          2111 non-null   Float64
#  3   Weight                          2111 non-null   Float64
#  4   family_history_with_overweight  2111 non-null   string
#  5   FAVC                            2111 non-null   string
#  6   FCVC                            2111 non-null   Float64
#  7   NCP                             2111 non-null   Float64
#  8   CAEC                            2111 non-null   string
#  9   SMOKE                           2111 non-null   string
#  10  CH2O                            2111 non-null   Float64
#  11  SCC                             2111 non-null   string
#  12  FAF                             2111 non-null   Float64
#  13  TUE                             2111 non-null   Float64
#  14  CALC                            2111 non-null   string
#  15  MTRANS                          2111 non-null   string
#  16  NObeyesdad                      2111 non-null   string
# dtypes: Float64(7), Int64(1), string(9)
# memory usage: 297.0 KB
# None
# ========================================================================================
# <StringArray>
# [      'Normal_Weight',  'Overweight_Level_I', 'Overweight_Level_II',
#       'Obesity_Type_I', 'Insufficient_Weight',     'Obesity_Type_II',
#     'Obesity_Type_III']
# Length: 7, dtype: string
# ========================================================================================
# 0    Obesity_Type_I
# Name: NObeyesdad, dtype: string
# ========================================================================================
# Mean:
#  Age       24.315964
# Height      1.70162
# Weight    86.586035
# FCVC       2.418986
# NCP        2.685651
# CH2O       2.008053
# FAF        1.010313
# TUE        0.657861
# Name: mean, dtype: Float64
# Standard Deviation:
#  Age        6.357078
# Height     0.093368
# Weight    26.191163
# FCVC       0.533996
# NCP        0.778079
# CH2O        0.61295
# FAF        0.850613
# TUE        0.608926
# Name: std, dtype: Float64
# Median:
#  Age        23.0
# Height      1.7
# Weight     83.0
# FCVC       2.39
# NCP         3.0
# CH2O        2.0
# FAF         1.0
# TUE       0.625
# Name: 50%, dtype: Float64
# 20th Percentile:
#  Age        19.0
# Height     1.62
# Weight    60.63
# FCVC        2.0
# NCP        2.12
# CH2O       1.35
# FAF        0.01
# TUE         0.0
# Name: 20%, dtype: Float64
# ========================================================================================
# a in section 2
#       Gender  Age  Height  Weight family_history_with_overweight FAVC  FCVC   NCP        CAEC SMOKE  CH2O  SCC   FAF    TUE        CALC                 MTRANS           NObeyesdad
# 5       Male   29    1.62    53.0                             no  yes   2.0   3.0   Sometimes    no   2.0   no   0.0    0.0   Sometimes             Automobile        Normal_Weight
# 13      Male   41     1.8    99.0                             no  yes   2.0   3.0   Sometimes    no   2.0   no   2.0    1.0  Frequently             Automobile       Obesity_Type_I
# 17    Female   29    1.53    78.0                             no  yes   2.0   1.0   Sometimes    no   2.0   no   0.0    0.0          no             Automobile       Obesity_Type_I
# 18    Female   30    1.71    82.0                            yes  yes   3.0   4.0  Frequently   yes   1.0   no   0.0    0.0          no             Automobile  Overweight_Level_II
# 21    Female   52    1.69    87.0                            yes  yes   3.0   1.0   Sometimes   yes   2.0   no   0.0    0.0          no             Automobile       Obesity_Type_I
# 30      Male   29    1.77    83.0                             no  yes   1.0   4.0  Frequently    no   3.0   no   0.0    1.0          no              Motorbike   Overweight_Level_I
# 31    Female   31    1.58    68.0                            yes   no   2.0   1.0   Sometimes    no   1.0   no   1.0    0.0   Sometimes  Public_Transportation  Overweight_Level_II
# 33      Male   39    1.79    90.0                             no   no   2.0   1.0   Sometimes    no   2.0   no   0.0    0.0   Sometimes  Public_Transportation  Overweight_Level_II
# 68      Male   30    1.76   112.0                            yes  yes   1.0   3.0          no   yes   2.0  yes   0.0    0.0  Frequently             Automobile      Obesity_Type_II
# 81      Male   30     1.8    91.0                            yes  yes   2.0   3.0  Frequently    no   2.0   no   0.0    0.0   Sometimes  Public_Transportation  Overweight_Level_II
# 89    Female   29     1.7    78.0                            yes  yes   3.0   3.0   Sometimes    no   1.0   no   2.0    1.0  Frequently             Automobile  Overweight_Level_II
# 92      Male   55    1.78    84.0                            yes   no   3.0   4.0  Frequently    no   3.0  yes   3.0    0.0  Frequently                Walking   Overweight_Level_I
# 104   Female   38    1.56    80.0                            yes  yes   2.0   3.0   Sometimes    no   2.0   no   0.0    0.0   Sometimes             Automobile       Obesity_Type_I
# 133   Female   61    1.65    66.0                             no  yes   3.0   3.0      Always    no   2.0   no   1.0    1.0  Frequently  Public_Transportation        Normal_Weight
# 134     Male   30    1.77   109.0                            yes  yes   3.0   3.0   Sometimes    no   1.0   no   2.0    0.0   Sometimes             Automobile       Obesity_Type_I
# 137     Male   44     1.6    80.0                            yes   no   2.0   3.0   Sometimes   yes   3.0   no   0.0    0.0          no              Motorbike       Obesity_Type_I
# 138     Male   31    1.76    75.0                            yes   no   3.0   3.0      Always    no   3.0  yes   3.0    0.0          no                   Bike        Normal_Weight
# 143   Female   34    1.68    75.0                             no  yes   3.0   1.0   Sometimes    no   1.0   no   0.0    0.0   Sometimes             Automobile   Overweight_Level_I
# 147   Female   36    1.63    80.0                            yes   no   3.0   3.0   Sometimes    no   1.0   no   0.0    0.0   Sometimes             Automobile       Obesity_Type_I
# 149   Female   32    1.67    90.0                            yes  yes   3.0   1.0   Sometimes    no   2.0   no   2.0    0.0   Sometimes             Automobile       Obesity_Type_I
# 151   Female   30    1.62    59.0                            yes  yes   3.0   3.0   Sometimes    no   2.0   no   2.0    0.0   Sometimes             Automobile        Normal_Weight
# 152   Female   38     1.5    60.0                            yes  yes   2.0   1.0      Always   yes   2.0   no   0.0    0.0   Sometimes             Automobile   Overweight_Level_I
# 153     Male   34    1.69    84.0                            yes   no   2.0   3.0   Sometimes    no   3.0   no   2.0    0.0          no             Automobile  Overweight_Level_II
# 155   Female   31    1.68    63.0                            yes  yes   3.0   1.0  Frequently    no   2.0   no   1.0    1.0   Sometimes             Automobile        Normal_Weight
# 156   Female   35    1.53    45.0                            yes   no   3.0   3.0  Frequently    no   1.0   no   0.0    1.0          no             Automobile        Normal_Weight
# 158   Female   40    1.55    62.0                            yes   no   3.0   3.0   Sometimes    no   3.0   no   0.0    0.0   Sometimes             Automobile   Overweight_Level_I
# 161     Male   55    1.65    80.0                             no  yes   2.0   3.0   Sometimes    no   2.0   no   1.0    0.0          no             Automobile  Overweight_Level_II
# 164     Male   35    1.77    85.0                            yes   no   3.0   3.0  Frequently    no   3.0   no   2.0    1.0   Sometimes             Automobile  Overweight_Level_II
# 165     Male   30    1.92   130.0                            yes   no   2.0   3.0   Sometimes   yes   1.0   no   1.0    0.0   Sometimes  Public_Transportation      Obesity_Type_II
# 166   Female   29    1.74    72.0                            yes   no   3.0   3.0      Always    no   2.0   no   0.0    0.0   Sometimes             Automobile        Normal_Weight
# 169   Female   45    1.63    77.0                            yes  yes   2.0   3.0  Frequently    no   1.0   no   0.0    0.0          no             Automobile  Overweight_Level_II
# 175   Female   38    1.64    59.8                            yes  yes   2.0   3.0   Sometimes    no   2.0   no   2.0    0.0          no  Public_Transportation        Normal_Weight
# 185   Female   31    1.62    68.0                             no   no   3.0   3.0   Sometimes    no   2.0   no   1.0    0.0   Sometimes             Automobile   Overweight_Level_I
# 186     Male   39    1.78    96.0                            yes   no   2.0   3.0   Sometimes    no   3.0   no   1.0    0.0  Frequently             Automobile       Obesity_Type_I
# 188     Male   35    1.78   105.0                            yes  yes   3.0   1.0          no    no   3.0   no   3.0    1.0  Frequently             Automobile       Obesity_Type_I
# 189   Female   33    1.63    62.0                            yes  yes   2.0   3.0   Sometimes    no   2.0   no   1.0    1.0          no  Public_Transportation        Normal_Weight
# 197     Male   41    1.75   118.0                            yes  yes   2.0   3.0   Sometimes    no   2.0   no   0.0    0.0   Sometimes                   Bike      Obesity_Type_II
# 201   Female   41    1.54    80.0                            yes  yes   2.0   3.0      Always    no   1.0   no   0.0    0.0   Sometimes             Automobile       Obesity_Type_I
# 203     Male   29    1.69    90.0                            yes   no   2.0   3.0   Sometimes    no   3.0   no   1.0    0.0   Sometimes             Automobile       Obesity_Type_I
# 207     Male   30    1.75    73.0                            yes   no   2.0   3.0          no    no   2.0  yes   1.0    0.0   Sometimes                Walking        Normal_Weight
# 228   Female   40    1.68    80.0                             no   no   3.0   3.0   Sometimes    no   3.0   no   0.0    0.0          no             Automobile  Overweight_Level_II
# 229     Male   32    1.75   120.0                            yes   no   3.0   3.0   Sometimes    no   3.0   no   0.0    2.0          no             Automobile      Obesity_Type_II
# 232   Female   51    1.59    50.0                            yes   no   3.0   3.0   Sometimes   yes   3.0  yes   2.0    0.0          no  Public_Transportation        Normal_Weight
# 233   Female   34    1.68    77.0                            yes   no   3.0   1.0   Sometimes    no   2.0   no   1.0    0.0   Sometimes             Automobile  Overweight_Level_II
# 243     Male   33    1.85    99.0                            yes  yes   2.0   3.0   Sometimes   yes   3.0   no   1.0    0.0   Sometimes             Automobile  Overweight_Level_II
# 252     Male   56    1.79    90.0                            yes   no   2.0   3.0   Sometimes   yes   2.0   no   1.0    0.0  Frequently             Automobile  Overweight_Level_II
# 261   Female   28     1.7    73.0                            yes   no   2.0   3.0  Frequently    no   2.0  yes   2.0    0.0   Sometimes                Walking   Overweight_Level_I
# 266   Female   39    1.65    50.0                             no  yes   3.0   4.0  Frequently    no   2.0   no   0.0    0.0   Sometimes  Public_Transportation  Insufficient_Weight
# 267     Male   38     1.7    78.0                             no  yes   3.0   3.0  Frequently    no   2.0   no   0.0    0.0  Frequently             Automobile  Overweight_Level_II
# 278   Female   32    1.57    57.0                            yes  yes   3.0   3.0   Sometimes    no   2.0   no   0.0    0.0   Sometimes             Automobile        Normal_Weight
# 316     Male   38    1.75    75.0                            yes   no   3.0   3.0  Frequently    no   1.0   no   2.0    1.0          no             Automobile        Normal_Weight
# 321     Male   38    1.75    75.0                            yes   no   3.0   3.0  Frequently    no   1.0   no   3.0    1.0          no             Automobile        Normal_Weight
# 324   Female   30    1.65    71.0                            yes  yes   2.0   3.0   Sometimes    no   1.0   no   0.0    0.0   Sometimes  Public_Transportation   Overweight_Level_I
# 358     Male   41    1.75   110.0                            yes   no   2.0   1.0   Sometimes    no   1.0   no   1.0    0.0  Frequently             Automobile      Obesity_Type_II
# 359   Female   33    1.56    48.0                            yes   no   2.0   3.0   Sometimes    no   2.0   no   1.0    0.0   Sometimes  Public_Transportation        Normal_Weight
# 361   Female   40    1.56    80.0                            yes  yes   2.0   1.0   Sometimes    no   2.0   no   2.0    0.0          no  Public_Transportation       Obesity_Type_I
# 362   Female   37    1.65    73.0                            yes   no   3.0   3.0   Sometimes    no   2.0   no   1.0    0.0   Sometimes             Automobile   Overweight_Level_I
# 366     Male   33    1.72    83.0                            yes  yes   2.0   1.0   Sometimes    no   2.0   no   3.0    0.0   Sometimes             Automobile  Overweight_Level_II
# 367   Female   40    1.58    63.0                             no  yes   2.0   3.0  Frequently    no   2.0   no   3.0    1.0   Sometimes  Public_Transportation   Overweight_Level_I
# 368   Female   37    1.68    83.0                            yes  yes   2.0   1.0   Sometimes    no   2.0   no   0.0    0.0          no             Automobile  Overweight_Level_II
# 375     Male   41     1.8    92.0                            yes  yes   2.0   1.0  Frequently    no   3.0   no   1.0    0.0   Sometimes             Automobile  Overweight_Level_II
# 376   Female   36    1.58    60.0                            yes   no   3.0   3.0   Sometimes    no   1.0   no   2.0    0.0   Sometimes             Automobile        Normal_Weight
# 382   Female   29     1.6    56.0                            yes   no   2.0   3.0  Frequently    no   1.0   no   0.0    1.0   Sometimes  Public_Transportation        Normal_Weight
# 387   Female   37     1.5    75.0                            yes  yes   2.0   3.0  Frequently    no   1.0   no   0.0    0.0   Sometimes              Motorbike       Obesity_Type_I
# 396   Female   38    1.55    59.0                            yes   no   3.0   3.0   Sometimes    no   1.0   no   2.0    1.0  Frequently             Automobile        Normal_Weight
# 404     Male   34    1.78    73.0                             no  yes   2.0   3.0   Sometimes    no   2.0   no   3.0    1.0   Sometimes             Automobile        Normal_Weight
# 406     Male   33    1.76    66.5                             no   no   2.0   3.0   Sometimes    no   2.0   no   3.0    1.0   Sometimes             Automobile        Normal_Weight
# 409   Female   33    1.55    55.0                            yes  yes   3.0   1.0   Sometimes    no   3.0   no   2.0    1.0   Sometimes  Public_Transportation        Normal_Weight
# 412     Male   33    1.85    85.0                             no  yes   2.0   3.0  Frequently    no   2.0   no   1.0    0.0   Sometimes             Automobile        Normal_Weight
# 413     Male   33    1.75    85.0                             no   no   2.0   3.0   Sometimes    no   2.0  yes   1.0    0.0   Sometimes  Public_Transportation  Overweight_Level_II
# 414     Male   33    1.83   113.0                            yes  yes   2.0   1.0      Always    no   2.0   no   1.0    2.0  Frequently             Automobile       Obesity_Type_I
# 416     Male   34    1.84    88.0                             no  yes   3.0   3.0   Sometimes    no   1.0  yes   2.0    0.0          no             Automobile   Overweight_Level_I
# 419     Male   29    1.62    89.0                            yes  yes   1.0   3.0   Sometimes    no   1.0   no   0.0    0.0   Sometimes  Public_Transportation       Obesity_Type_I
# 423     Male   33    1.85    93.0                            yes  yes   2.0   3.0   Sometimes    no   1.0   no   1.0    1.0   Sometimes                Walking  Overweight_Level_II
# 424     Male   33    1.74    76.0                             no   no   2.0   3.0   Sometimes    no   1.0   no   0.0    2.0   Sometimes                Walking   Overweight_Level_I
# 456   Female   33    1.59    60.0                             no  yes   3.0   1.0  Frequently    no   2.0   no   0.0    0.0          no  Public_Transportation        Normal_Weight
# 484   Female   36    1.65    80.0                            yes  yes   2.0   3.0   Sometimes    no   1.0   no   0.0    2.0          no             Automobile  Overweight_Level_II
# 492     Male   45     1.7    86.0                             no  yes   3.0   3.0  Frequently    no   1.0   no   0.0    0.0          no             Automobile  Overweight_Level_II
# 549   Female   30    1.61   49.52                            yes  yes  2.06   3.9  Frequently    no   2.0   no  0.82    0.0          no  Public_Transportation  Insufficient_Weight
# 550   Female   32    1.64   46.66                            yes  yes   3.0  3.11  Frequently    no  2.72   no  1.44    0.0          no  Public_Transportation  Insufficient_Weight
# 623   Female   35    1.69    50.0                            yes  yes  2.65   3.8  Frequently    no   1.6   no  0.17  0.097          no  Public_Transportation  Insufficient_Weight
# 751   Female   42    1.72   82.92                             no  yes  2.82  3.36   Sometimes    no  2.72   no   3.0  0.266   Sometimes             Automobile   Overweight_Level_I
# 756   Female   34    1.64    74.8                            yes   no   3.0  1.15   Sometimes    no  1.07   no  0.68    0.0   Sometimes             Automobile   Overweight_Level_I
# 759   Female   35    1.53    62.9                             no  yes   2.0  2.11   Sometimes    no  1.46   no   0.0  0.997   Sometimes             Automobile   Overweight_Level_I
# 760   Female   37    1.55   62.34                            yes  yes  2.39   3.0   Sometimes    no  2.95   no   0.0  0.369   Sometimes             Automobile   Overweight_Level_I
# 765   Female   31    1.63    68.8                            yes  yes  2.05   3.0   Sometimes    no  1.97   no  0.23    0.0   Sometimes             Automobile   Overweight_Level_I
# 777   Female   29    1.67    71.6                            yes  yes   2.0   3.0   Sometimes    no   1.7   no  1.68    0.0   Sometimes             Automobile   Overweight_Level_I
# 782   Female   33    1.72   72.75                            yes  yes   2.0   3.0   Sometimes    no   1.0   no   0.0  1.339   Sometimes             Automobile   Overweight_Level_I
# 787   Female   35    1.67   73.19                            yes   no   3.0  2.81   Sometimes    no  1.59   no  0.18    0.0   Sometimes             Automobile   Overweight_Level_I
# 789   Female   37    1.59   63.32                            yes  yes  2.37   3.0   Sometimes    no   2.0   no  2.89  0.481   Sometimes             Automobile   Overweight_Level_I
# 795     Male   30    1.82   87.67                             no  yes   3.0   3.0   Sometimes    no  1.17   no   2.0    0.0          no             Automobile   Overweight_Level_I
# 796   Female   32    1.66   73.64                            yes  yes   2.0   3.0   Sometimes    no   1.0   no   0.0  1.112   Sometimes             Automobile   Overweight_Level_I
# 803     Male   28    1.81   87.29                             no  yes   3.0   3.0   Sometimes    no  1.21   no   2.0    0.0          no             Automobile   Overweight_Level_I
# 813   Female   42    1.77   75.63                            yes  yes   3.0  2.95   Sometimes    no  2.11   no  0.38    0.0   Sometimes             Automobile   Overweight_Level_I
# 820   Female   33    1.67   74.81                            yes  yes  2.95   1.2   Sometimes    no   1.0   no   0.0  0.174   Sometimes             Automobile   Overweight_Level_I
# 821   Female   33    1.68   74.96                            yes  yes  2.29  1.56   Sometimes    no   1.0   no   0.0  0.388   Sometimes             Automobile   Overweight_Level_I
# 825   Female   37    1.51   63.18                            yes  yes  2.05  1.05   Sometimes    no   2.0   no  0.15  0.226   Sometimes             Automobile   Overweight_Level_I
# 826   Female   40    1.56   62.87                            yes  yes  2.95   3.0   Sometimes    no  2.43   no  0.12   0.36   Sometimes             Automobile   Overweight_Level_I
# 827   Female   39    1.55   63.01                            yes  yes  2.87   3.0   Sometimes    no  2.97   no  2.16  0.306   Sometimes             Automobile   Overweight_Level_I
# 835   Female   29    1.64   69.91                            yes  yes  2.37   3.0   Sometimes    no  1.93   no  1.58    0.0   Sometimes             Automobile   Overweight_Level_I
# 836   Female   31    1.69   71.93                            yes  yes  2.62   3.0   Sometimes    no  1.77   no  0.76  0.687   Sometimes             Automobile   Overweight_Level_I
# 856   Female   28     1.7   74.24                            yes  yes   2.0   3.0   Sometimes    no   2.0   no  1.72    0.0   Sometimes             Automobile   Overweight_Level_I
# 857     Male   29    1.77   82.05                            yes  yes  1.06  3.99   Sometimes    no  2.03   no  0.82  0.895   Sometimes  Public_Transportation   Overweight_Level_I
# 862   Female   30    1.65   73.58                            yes  yes   2.0   3.0   Sometimes    no   1.0   no   0.0  0.019   Sometimes             Automobile   Overweight_Level_I
# 863   Female   31    1.65   69.17                            yes  yes   2.0   3.0   Sometimes    no  1.13   no  0.06    0.0   Sometimes             Automobile   Overweight_Level_I
# 870   Female   35    1.65   73.92                            yes   no   3.0  2.73   Sometimes    no  1.62   no   0.9    0.0   Sometimes             Automobile   Overweight_Level_I
# 873   Female   40    1.57   62.21                            yes  yes  2.25   3.0   Sometimes    no  2.76   no  1.02  0.213   Sometimes             Automobile   Overweight_Level_I
# 882     Male   33    1.84   87.86                             no  yes  2.81  2.61   Sometimes    no  1.86   no   2.0  0.516          no             Automobile   Overweight_Level_I
# 883   Female   33    1.73   75.92                            yes  yes  2.01  2.63   Sometimes    no  1.05   no  0.55   0.48   Sometimes             Automobile   Overweight_Level_I
# 902   Female   39    1.74   86.93                             no  yes  2.84  3.06   Sometimes    no  1.13   no  2.83  0.045   Sometimes             Automobile   Overweight_Level_I
# 903   Female   40    1.74   80.91                             no  yes  2.42   3.2   Sometimes    no  1.35   no  0.15  1.083   Sometimes             Automobile   Overweight_Level_I
# 910   Female   34    1.68   74.89                            yes  yes   3.0  1.14   Sometimes    no   1.0   no  0.26    0.0   Sometimes             Automobile   Overweight_Level_I
# 915   Female   39    1.55   62.34                            yes  yes  2.96  2.97   Sometimes    no  2.87   no   0.0  0.549   Sometimes             Automobile   Overweight_Level_I
# 916   Female   39    1.57   62.86                            yes  yes   2.0   3.0   Sometimes    no  2.53   no  0.27  0.806   Sometimes             Automobile   Overweight_Level_I
# 917   Female   37    1.53   62.42                            yes  yes  2.29  2.85   Sometimes    no  2.64   no   0.0  0.991   Sometimes             Automobile   Overweight_Level_I
# 924   Female   30    1.64   69.24                            yes  yes  2.03   3.0   Sometimes    no  1.83   no  0.48    0.0   Sometimes             Automobile   Overweight_Level_I
# 1186    Male   35    1.75   84.78                            yes  yes  2.63  2.98   Sometimes    no  2.78   no  2.67  0.905          no             Automobile  Overweight_Level_II
# 1187    Male   36    1.69   83.33                            yes  yes   2.0  1.01   Sometimes    no  2.14   no  1.06    0.0          no             Automobile  Overweight_Level_II
# 1190    Male   32    1.83    91.5                            yes  yes   2.0   2.7   Sometimes    no  2.04   no   0.6  0.017   Sometimes             Automobile  Overweight_Level_II
# 1194    Male   30    1.84   93.61                            yes  yes  2.05  2.95   Sometimes    no  1.31   no  1.44  0.934   Sometimes  Public_Transportation  Overweight_Level_II
# 1197    Male   33    1.69   83.99                            yes  yes   2.0  2.47   Sometimes    no  2.45   no  0.93    0.0          no             Automobile  Overweight_Level_II
# 1199    Male   32    1.76   87.91                            yes  yes   2.0   1.8   Sometimes    no  1.86   no  1.08  0.219   Sometimes  Public_Transportation  Overweight_Level_II
# 1200    Male   32    1.85   98.91                            yes  yes   2.4  2.62   Sometimes    no  2.54   no  1.03  0.606   Sometimes             Automobile  Overweight_Level_II
# 1204  Female   35    1.66   80.14                            yes  yes   2.0   3.0   Sometimes    no  1.99   no  0.04  1.529          no             Automobile  Overweight_Level_II
# 1205  Female   34    1.68   77.36                            yes  yes  2.77  2.14   Sometimes    no  1.87   no  0.97  0.692          no             Automobile  Overweight_Level_II
# 1207    Male   40    1.72   86.46                            yes  yes  2.33  1.31   Sometimes    no  1.95   no   0.6    0.0          no             Automobile  Overweight_Level_II
# 1208  Female   46    1.69   80.41                            yes  yes  2.08   3.0   Sometimes    no  1.03   no  0.65    0.0          no             Automobile  Overweight_Level_II
# 1211    Male   31    1.78  102.87                            yes  yes  2.27   3.0   Sometimes    no  1.77   no   2.0  0.414   Sometimes             Automobile       Obesity_Type_I
# 1212    Male   40    1.79  101.78                            yes  yes  2.33  2.11   Sometimes    no   2.5   no   3.0    1.0   Sometimes             Automobile       Obesity_Type_I
# 1213  Female   31    1.56   78.23                            yes  yes  2.14  2.09   Sometimes    no  1.51   no   0.0    0.0   Sometimes  Public_Transportation       Obesity_Type_I
# 1215  Female   44    1.57   81.83                            yes  yes  2.91   1.0   Sometimes    no   2.0   no  1.31    0.0          no             Automobile       Obesity_Type_I
# ...
# 1702    Male   34    1.71  103.07                            yes  yes  2.56   2.1   Sometimes    no  1.46   no  1.17  0.412          no  Public_Transportation      Obesity_Type_II
# 1711    Male   29    1.76   113.5                            yes  yes  2.32   3.0   Sometimes    no  2.16   no   0.0  1.465   Sometimes             Automobile      Obesity_Type_II
# 1712    Male   30    1.76  113.22                            yes  yes  2.18   3.0   Sometimes    no  2.09   no   0.0  1.439   Sometimes             Automobile      Obesity_Type_II
# 1719    Male   30    1.76  111.64                            yes  yes  1.26  3.22   Sometimes    no  1.98   no  0.48    0.0   Sometimes             Automobile      Obesity_Type_II
# 1720    Male   30    1.76  111.95                            yes  yes  1.07  3.66   Sometimes    no  1.98   no  0.05    0.0   Sometimes             Automobile      Obesity_Type_II
gender  Age  Height  Weight family_history_with_overweight FAVC  FCVC  NCP       CAEC SMOKE  CH2O SCC  FAF  TUE        CALC                 MTRANS           NObeyesdad
# 2   Male   23     1.8    77.0                            yes   no   2.0  3.0  Sometimes    no   2.0  no  2.0  1.0  Frequently  Public_Transportation        Normal_Weight
# 3   Male   27     1.8    87.0                             no   no   3.0  3.0  Sometimes    no   2.0  no  2.0  0.0  Frequently                Walking   Overweight_Level_I
# 4   Male   22    1.78    89.8                             no   no   2.0  1.0  Sometimes    no   2.0  no  0.0  0.0   Sometimes  Public_Transportation  Overweight_Level_II
# 5   Male   29    1.62    53.0                             no  yes   2.0  3.0  Sometimes    no   2.0  no  0.0  0.0   Sometimes             Automobile        Normal_Weight
# 7   Male   22    1.64    53.0                             no   no   2.0  3.0  Sometimes    no   2.0  no  3.0  0.0   Sometimes  Public_Transportation        Normal_Weight
# Number of records where Gender starts with 'M': 1068
#
# ===============
#
# Total number of duplicate rows: 24
#
# ===============
#
# Age was Integer now It is : string
#
#    Gender Age  Height  Weight family_history_with_overweight FAVC  FCVC  NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS           NObeyesdad
# 0  Female  21    1.62    64.0                            yes   no   2.0  3.0  Sometimes    no   2.0   no  0.0  1.0          no  Public_Transportation        Normal_Weight
# 1  Female  21    1.52    56.0                            yes   no   3.0  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation        Normal_Weight
# 2    Male  23     1.8    77.0                            yes   no   2.0  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently  Public_Transportation        Normal_Weight
# 3    Male  27     1.8    87.0                             no   no   3.0  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently                Walking   Overweight_Level_I
# 4    Male  22    1.78    89.8                             no   no   2.0  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation  Overweight_Level_II
#
# ===============
#
#     Gender           NObeyesdad  Count
# 0   Female  Insufficient_Weight    173
# 1   Female        Normal_Weight    141
# 2   Female       Obesity_Type_I    156
# 3   Female      Obesity_Type_II      2
# 4   Female     Obesity_Type_III    323
# 5   Female   Overweight_Level_I    145
# 6   Female  Overweight_Level_II    103
# 7     Male  Insufficient_Weight     99
# 8     Male        Normal_Weight    146
# 9     Male       Obesity_Type_I    195
# 10    Male      Obesity_Type_II    295
# 11    Male     Obesity_Type_III      1
# 12    Male   Overweight_Level_I    145
# 13    Male  Overweight_Level_II    187
#
# ===============
#
# Missing values in each column:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64
#
# Total number of missing values in the dataset: 0
#
# ===============
#
# Missing values in each column before handling:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64
#
# Total missing values: 0
#
#
# No missing values found in the dataset.
#
# ===============
#
# Number of records in each Age bin:
#
# Age_Binned
# (13.953, 23.4]    1239
# (23.4, 32.8]       627
# (32.8, 42.2]       219
# (42.2, 51.6]        18
# (51.6, 61.0]         8
# Name: count, dtype: int64
#
# ===============
#
# Max weight row
#
#     Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 344   Male  18.0    1.87   173.0                            yes  yes   3.0
#
#      NCP        CAEC SMOKE  CH2O SCC  FAF  TUE       CALC  \
# 344  3.0  Frequently    no   2.0  no  2.0  1.0  Sometimes
#
#                     MTRANS        NObeyesdad      Age_Binned
# 344  Public_Transportation  Obesity_Type_III  (13.953, 23.4]
#
# ===============
#       Gender       Age    Height    Weight family_history_with_overweight  \
# 0     Female -0.521741 -0.874380 -0.862558                            yes
# 1     Female -0.521741 -1.945660 -1.168077                            yes
# 2       Male -0.207057  1.053924 -0.366089                            yes
# 3       Male  0.422312  1.053924  0.015809                             no
# 4       Male -0.364399  0.839668  0.122741                             no
# ...      ...       ...       ...       ...                            ...
# 2106  Female -0.521741  0.089772  1.711821                            yes
# 2107  Female -0.364399  0.518284  1.800804                            yes
# 2108  Female -0.207057  0.518284  1.798894                            yes
# 2109  Female -0.049714  0.411156  1.785909                            yes
# 2110  Female -0.049714  0.411156  1.790492                            yes
#
#      FAVC      FCVC       NCP       CAEC SMOKE  CH2O  SCC   FAF    TUE  \
# 0      no -0.784810  0.404102  Sometimes    no   2.0   no   0.0    1.0
# 1      no  1.088307  0.404102  Sometimes   yes   3.0  yes   3.0    0.0
# 2      no -0.784810  0.404102  Sometimes    no   2.0   no   2.0    1.0
# 3      no  1.088307  0.404102  Sometimes    no   2.0   no   2.0    0.0
# 4      no -0.784810 -2.166941  Sometimes    no   2.0   no   0.0    0.0
# ...   ...       ...       ...        ...   ...   ...  ...   ...    ...
# 2106  yes  1.088307  0.404102  Sometimes    no  1.73   no  1.68  0.906
# 2107  yes  1.088307  0.404102  Sometimes    no  2.01   no  1.34  0.599
# 2108  yes  1.088307  0.404102  Sometimes    no  2.05   no  1.41  0.646
# 2109  yes  1.088307  0.404102  Sometimes    no  2.85   no  1.14  0.586
# 2110  yes  1.088307  0.404102  Sometimes    no  2.86   no  1.03  0.714
#
#             CALC                 MTRANS           NObeyesdad      Age_Binned
# 0             no  Public_Transportation        Normal_Weight  (13.953, 23.4]
# 1      Sometimes  Public_Transportation        Normal_Weight  (13.953, 23.4]
# 2     Frequently  Public_Transportation        Normal_Weight  (13.953, 23.4]
# 3     Frequently                Walking   Overweight_Level_I    (23.4, 32.8]
# 4      Sometimes  Public_Transportation  Overweight_Level_II  (13.953, 23.4]
# ...          ...                    ...                  ...             ...
# 2106   Sometimes  Public_Transportation     Obesity_Type_III  (13.953, 23.4]
# 2107   Sometimes  Public_Transportation     Obesity_Type_III  (13.953, 23.4]
# 2108   Sometimes  Public_Transportation     Obesity_Type_III  (13.953, 23.4]
# 2109   Sometimes  Public_Transportation     Obesity_Type_III    (23.4, 32.8]
# 2110   Sometimes  Public_Transportation     Obesity_Type_III    (23.4, 32.8]
#
# [2111 rows x 18 columns]
# pca operation
# PCA Result:
#            PC1       PC2
# 0    -1.529383 -0.143360
# 1    -2.065816 -0.118542
# 2    -0.648907 -0.057469
# 3     0.036152  0.179130
# 4     0.206651 -0.164197
# ...        ...       ...
# 2106  2.999229 -0.383131
# 2107  3.159374 -0.323486
# 2108  3.159529 -0.256522
# 2109  3.140500 -0.188363
# 2110  3.148560 -0.188894
#
# [2111 rows x 2 columns]
# ===============
# ===============

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from pandas import read_csv
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
dataset=pd.read_csv('Obesity.csv')
dataset = dataset.convert_dtypes()

#Data Preparation Tasks
#==== (a) Apply a filter to select rows based on a specific condition of your choice (e.g., select records where a value exceeds a certain threshold)
filtered_data = dataset[dataset["Age"] > 27]
print(filtered_data.to_string())
print("\n===============\n")
#====

#==== (b) Identify records where a chosen attribute starts with a specific letter and count how many records match this condition
filtered_data = dataset[dataset["Gender"].str.startswith("M")]
count = len(filtered_data)
print(filtered_data.head().to_string())
print(f"Number of records where Gender starts with 'M': {count}")
print("\n===============\n")
#====

#==== (c) Determine the total number of duplicate rows and remove them if found
duplicate_count = dataset.duplicated().sum()
print(f"Total number of duplicate rows: {duplicate_count}")
dataset_cleaned = dataset.drop_duplicates()
#print(dataset_cleaned)
print("\n===============\n")
#====

#==== (d) Convert the data type of a numerical column from integer to string
dataset["Age"] = dataset["Age"].astype("string")
print(f"Age was Integer now It is : {dataset["Age"].dtype}\n")
print(dataset.head().to_string())
dataset["Age"] = dataset["Age"].astype("float64")
print("\n===============\n")

#====

#==== (e) Group the dataset based on two selected categorical features and analyze the results
grouped_data = dataset.groupby(["Gender", "NObeyesdad"]).size().reset_index(name="Count")
print(grouped_data)
print("\n===============\n")
#====

#==== (f) Check for the existence of missing values within the dataset
missing_values = dataset.isnull().sum()
print("Missing values in each column:")
print(missing_values)
total_missing = missing_values.sum()
print(f"\nTotal number of missing values in the dataset: {total_missing}")
print("\n===============\n")
#====

#==== (g) If any missing values are found, replace them with the median or mode as appropriate
missing_values = dataset.isnull().sum()
total_missing = missing_values.sum()
print("Missing values in each column before handling:")
print(missing_values)
print(f"\nTotal missing values: {total_missing}\n")
if total_missing > 0:
    for column in dataset.columns:
        if dataset[column].dtype in ["int64", "float64"]:
            dataset[column].fillna(dataset[column].median(), inplace=True)
        else:
            dataset[column].fillna(dataset[column].mode()[0], inplace=True)
    missing_values_after = dataset.isnull().sum()
    print("\nMissing values in each column after handling:")
    print(missing_values_after)
    print("\nAll missing values have been handled successfully!")
else:
    print("\nNo missing values found in the dataset.")
print("\n===============\n")
#====

#==== (h) Divide a chosen numerical column into 5 equal-width bins and count the number of records in each bin
dataset["Age_Binned"] = pd.cut(dataset["Age"].astype(float), bins=5)
bin_counts = dataset["Age_Binned"].value_counts().sort_index()
print(f"Number of records in each Age bin:\n")
print(bin_counts)
print("\n===============\n")

#==== (i)  Identify and print the row corresponding to the maximum value of a selected numerical feature.
max_weight_row = dataset[dataset['Weight'] == dataset['Weight'].max()]
print("Max weight row\n")
print(max_weight_row)
print("\n===============\n")
#====



#==== (j) Construct a boxplot for an attribute you consider significant and justify the selection
#FCVC Frequency of vegetable consumption (scale from 1 to 3).
# df = pd.DataFrame(dataset)
# sns.set(style="whitegrid")
# plt.figure(figsize=(8, 6))
# sns.boxplot(x=df['FCVC'])
# plt.title("Boxplot of Frequency of Vegetable Consumption (FCVC)", fontsize=16)
# plt.xlabel("FCVC (1=Low, 2=Medium, 3=High)", fontsize=12)
# plt.show()
# Convert the 'Age' column to numeric type
dataset['Age'] = pd.to_numeric(dataset['Age'], errors='coerce')
# Create the boxplot
plt.boxplot(dataset['Age'].dropna())  # Drop any NaN values that may have been introduced
plt.title("Boxplot of Age", fontsize=16)
plt.show()
#====


#==== (k) Generate a histogram for a chosen attribute and provide an explanation for its relevance.
df = pd.DataFrame(dataset)
sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))
sns.histplot(df['NCP'], bins=4, kde=False, color='skyblue', edgecolor='black')
plt.title("Histogram of Number of Main Meals Per Day (NCP)", fontsize=16)
plt.xlabel("Number of Meals", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.xticks(range(int(min(df['NCP'])), int(max(df['NCP'])) + 1, 1))  # Set ticks in steps of 1
plt.show()

# Explanation for why NCP was chosen for the histogram:
"""
We chose the 'NCP' (Number of Main Meals Per Day) attribute for the histogram because it provides
insight into dietary habits. Understanding how many main meals people consume in a day can help with
various analyses related to health, nutrition, and lifestyle.

Histograms are particularly useful for visualizing the distribution of discrete data, and NCP fits this
category as it is a count variable (integer values).

This histogram allows us to:
1. Identify the most common number of main meals people have per day.
2. Check the distribution of meals and whether people tend to have more or fewer meals on average.
3. Help us understand if there is any skewness in the data toward people with fewer or more meals.
4. Inform decisions regarding dietary recommendations, public health initiatives, or understanding
   lifestyle habits in different populations.
"""

#===

#=== (l) Create a scatterplot using two attributes and interpret the relationship observed.
df = pd.DataFrame(dataset)

# Set the style for the plot
sns.set(style="whitegrid")

# Create the scatterplot for AGE vs. Weight
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='Age', y='Weight', color='purple')

# Add a title and labels
plt.title("Scatterplot of AGE vs. Weight", fontsize=16)
plt.xlabel("Age", fontsize=12)
plt.ylabel("Weight", fontsize=12)

# Show the plot
plt.show()

# Interpretation of the scatterplot:
"""
The scatterplot visualizes the relationship between AGE and Weight.

Each point on the plot represents an individual. The x-axis represents their AGE,
and the y-axis represents their Weight.

By observing the scatterplot, we can interpret:
- If there is a positive or negative correlation between AGE and Weight.
- Whether the points are scattered randomly or if there's a trend, such as older individuals having higher or lower weights.
- Whether there are any outliers in the data, such as individuals who are significantly heavier or lighter than expected for their age.

For example, if the points tend to rise from left to right, it might indicate a positive correlation between AGE and Weight, where older individuals tend to weigh more.
Conversely, if the points tend to decrease from left to right, it might suggest a negative correlation.
"""

#===

#=== (m)
# Create DataFrame
df = pd.DataFrame(dataset)

# Initialize the StandardScaler
scaler = StandardScaler()

# Select numerical columns that you want to standardize
numerical_cols = ['Age', 'Height', 'Weight', 'FCVC', 'NCP']

# Apply StandardScaler to the selected columns
df[numerical_cols] = scaler.fit_transform(df[numerical_cols])

# Display the standardized data
print(df)
print("pca operation")

#n) Perform PCA (Principal Component Analysis) to reduce dimensionality to two components, andvisualize the dataset before and after applying PCA.
pca = PCA(n_components=2)
X = dataset.iloc[:, :-1]
X = pd.get_dummies(X)
X = X.dropna()
X = X.values
X = X.astype(float)
X = (X - X.mean()) / X.std()
pca_result = pca.fit_transform(X)
pca_result = pd.DataFrame(pca_result, columns=["PC1", "PC2"])
print("PCA Result:")
print(pca_result)
# Visualize the dataset before PCA
plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1], alpha=0.5)
plt.title('Dataset before PCA')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# Visualize the dataset after PCA
plt.figure(figsize=(8, 6))
plt.scatter(pca_result["PC1"], pca_result["PC2"], alpha=0.5)
plt.title('Dataset after PCA')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()
print("\n===============\n")

#o) Analyze the correlation between numerical features using a heatmap.
# Select only numeric columns
numeric_dataset = dataset.select_dtypes(include=[float, int])

# Compute the correlation matrix
correlation_matrix = numeric_dataset.corr()
plt.figure(figsize=(10, 8))
plt.title("Correlation Heatmap")
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.show()
print("\n===============\n")
# Out:
#       Gender  Age  Height  Weight family_history_with_overweight FAVC  FCVC   NCP        CAEC SMOKE  CH2O  SCC   FAF    TUE        CALC                 MTRANS           NObeyesdad
# 5       Male   29    1.62    53.0                             no  yes   2.0   3.0   Sometimes    no   2.0   no   0.0    0.0   Sometimes             Automobile        Normal_Weight
# 13      Male   41     1.8    99.0                             no  yes   2.0   3.0   Sometimes    no   2.0   no   2.0    1.0  Frequently             Automobile       Obesity_Type_I
# 17    Female   29    1.53    78.0                             no  yes   2.0   1.0   Sometimes    no   2.0   no   0.0    0.0          no             Automobile       Obesity_Type_I
# 18    Female   30    1.71    82.0                            yes  yes   3.0   4.0  Frequently   yes   1.0   no   0.0    0.0          no             Automobile  Overweight_Level_II
# 21    Female   52    1.69    87.0                            yes  yes   3.0   1.0   Sometimes   yes   2.0   no   0.0    0.0          no             Automobile       Obesity_Type_I
# 30      Male   29    1.77    83.0                             no  yes   1.0   4.0  Frequently    no   3.0   no   0.0    1.0          no              Motorbike   Overweight_Level_I
# 31    Female   31    1.58    68.0                            yes   no   2.0   1.0   Sometimes    no   1.0   no   1.0    0.0   Sometimes  Public_Transportation  Overweight_Level_II
# 33      Male   39    1.79    90.0                             no   no   2.0   1.0   Sometimes    no   2.0   no   0.0    0.0   Sometimes  Public_Transportation  Overweight_Level_II
# 68      Male   30    1.76   112.0                            yes  yes   1.0   3.0          no   yes   2.0  yes   0.0    0.0  Frequently             Automobile      Obesity_Type_II
# 81      Male   30     1.8    91.0                            yes  yes   2.0   3.0  Frequently    no   2.0   no   0.0    0.0   Sometimes  Public_Transportation  Overweight_Level_II
# 89    Female   29     1.7    78.0                            yes  yes   3.0   3.0   Sometimes    no   1.0   no   2.0    1.0  Frequently             Automobile  Overweight_Level_II
# 92      Male   55    1.78    84.0                            yes   no   3.0   4.0  Frequently    no   3.0  yes   3.0    0.0  Frequently                Walking   Overweight_Level_I
# 104   Female   38    1.56    80.0                            yes  yes   2.0   3.0   Sometimes    no   2.0   no   0.0    0.0   Sometimes             Automobile       Obesity_Type_I
# 133   Female   61    1.65    66.0                             no  yes   3.0   3.0      Always    no   2.0   no   1.0    1.0  Frequently  Public_Transportation        Normal_Weight
# 134     Male   30    1.77   109.0                            yes  yes   3.0   3.0   Sometimes    no   1.0   no   2.0    0.0   Sometimes             Automobile       Obesity_Type_I
# 137     Male   44     1.6    80.0                            yes   no   2.0   3.0   Sometimes   yes   3.0   no   0.0    0.0          no              Motorbike       Obesity_Type_I
# 138     Male   31    1.76    75.0                            yes   no   3.0   3.0      Always    no   3.0  yes   3.0    0.0          no                   Bike        Normal_Weight
# 143   Female   34    1.68    75.0                             no  yes   3.0   1.0   Sometimes    no   1.0   no   0.0    0.0   Sometimes             Automobile   Overweight_Level_I
# 147   Female   36    1.63    80.0                            yes   no   3.0   3.0   Sometimes    no   1.0   no   0.0    0.0   Sometimes             Automobile       Obesity_Type_I
# 149   Female   32    1.67    90.0                            yes  yes   3.0   1.0   Sometimes    no   2.0   no   2.0    0.0   Sometimes             Automobile       Obesity_Type_I
# 151   Female   30    1.62    59.0                            yes  yes   3.0   3.0   Sometimes    no   2.0   no   2.0    0.0   Sometimes             Automobile        Normal_Weight
# 152   Female   38     1.5    60.0                            yes  yes   2.0   1.0      Always   yes   2.0   no   0.0    0.0   Sometimes             Automobile   Overweight_Level_I
# 153     Male   34    1.69    84.0                            yes   no   2.0   3.0   Sometimes    no   3.0   no   2.0    0.0          no             Automobile  Overweight_Level_II
# 155   Female   31    1.68    63.0                            yes  yes   3.0   1.0  Frequently    no   2.0   no   1.0    1.0   Sometimes             Automobile        Normal_Weight
# 156   Female   35    1.53    45.0                            yes   no   3.0   3.0  Frequently    no   1.0   no   0.0    1.0          no             Automobile        Normal_Weight
# 158   Female   40    1.55    62.0                            yes   no   3.0   3.0   Sometimes    no   3.0   no   0.0    0.0   Sometimes             Automobile   Overweight_Level_I
# 161     Male   55    1.65    80.0                             no  yes   2.0   3.0   Sometimes    no   2.0   no   1.0    0.0          no             Automobile  Overweight_Level_II
# 164     Male   35    1.77    85.0                            yes   no   3.0   3.0  Frequently    no   3.0   no   2.0    1.0   Sometimes             Automobile  Overweight_Level_II
# 165     Male   30    1.92   130.0                            yes   no   2.0   3.0   Sometimes   yes   1.0   no   1.0    0.0   Sometimes  Public_Transportation      Obesity_Type_II
# 166   Female   29    1.74    72.0                            yes   no   3.0   3.0      Always    no   2.0   no   0.0    0.0   Sometimes             Automobile        Normal_Weight
# 169   Female   45    1.63    77.0                            yes  yes   2.0   3.0  Frequently    no   1.0   no   0.0    0.0          no             Automobile  Overweight_Level_II
# 175   Female   38    1.64    59.8                            yes  yes   2.0   3.0   Sometimes    no   2.0   no   2.0    0.0          no  Public_Transportation        Normal_Weight
# 185   Female   31    1.62    68.0                             no   no   3.0   3.0   Sometimes    no   2.0   no   1.0    0.0   Sometimes             Automobile   Overweight_Level_I
# 186     Male   39    1.78    96.0                            yes   no   2.0   3.0   Sometimes    no   3.0   no   1.0    0.0  Frequently             Automobile       Obesity_Type_I
# 188     Male   35    1.78   105.0                            yes  yes   3.0   1.0          no    no   3.0   no   3.0    1.0  Frequently             Automobile       Obesity_Type_I
# 189   Female   33    1.63    62.0                            yes  yes   2.0   3.0   Sometimes    no   2.0   no   1.0    1.0          no  Public_Transportation        Normal_Weight
# 197     Male   41    1.75   118.0                            yes  yes   2.0   3.0   Sometimes    no   2.0   no   0.0    0.0   Sometimes                   Bike      Obesity_Type_II
# 201   Female   41    1.54    80.0                            yes  yes   2.0   3.0      Always    no   1.0   no   0.0    0.0   Sometimes             Automobile       Obesity_Type_I
# 203     Male   29    1.69    90.0                            yes   no   2.0   3.0   Sometimes    no   3.0   no   1.0    0.0   Sometimes             Automobile       Obesity_Type_I
# 207     Male   30    1.75    73.0                            yes   no   2.0   3.0          no    no   2.0  yes   1.0    0.0   Sometimes                Walking        Normal_Weight
# 228   Female   40    1.68    80.0                             no   no   3.0   3.0   Sometimes    no   3.0   no   0.0    0.0          no             Automobile  Overweight_Level_II
# 229     Male   32    1.75   120.0                            yes   no   3.0   3.0   Sometimes    no   3.0   no   0.0    2.0          no             Automobile      Obesity_Type_II
# 232   Female   51    1.59    50.0                            yes   no   3.0   3.0   Sometimes   yes   3.0  yes   2.0    0.0          no  Public_Transportation        Normal_Weight
# 233   Female   34    1.68    77.0                            yes   no   3.0   1.0   Sometimes    no   2.0   no   1.0    0.0   Sometimes             Automobile  Overweight_Level_II
# 243     Male   33    1.85    99.0                            yes  yes   2.0   3.0   Sometimes   yes   3.0   no   1.0    0.0   Sometimes             Automobile  Overweight_Level_II
# 252     Male   56    1.79    90.0                            yes   no   2.0   3.0   Sometimes   yes   2.0   no   1.0    0.0  Frequently             Automobile  Overweight_Level_II
# 261   Female   28     1.7    73.0                            yes   no   2.0   3.0  Frequently    no   2.0  yes   2.0    0.0   Sometimes                Walking   Overweight_Level_I
# 266   Female   39    1.65    50.0                             no  yes   3.0   4.0  Frequently    no   2.0   no   0.0    0.0   Sometimes  Public_Transportation  Insufficient_Weight
# 267     Male   38     1.7    78.0                             no  yes   3.0   3.0  Frequently    no   2.0   no   0.0    0.0  Frequently             Automobile  Overweight_Level_II
# 278   Female   32    1.57    57.0                            yes  yes   3.0   3.0   Sometimes    no   2.0   no   0.0    0.0   Sometimes             Automobile        Normal_Weight
# 316     Male   38    1.75    75.0                            yes   no   3.0   3.0  Frequently    no   1.0   no   2.0    1.0          no             Automobile        Normal_Weight
# 321     Male   38    1.75    75.0                            yes   no   3.0   3.0  Frequently    no   1.0   no   3.0    1.0          no             Automobile        Normal_Weight
# 324   Female   30    1.65    71.0                            yes  yes   2.0   3.0   Sometimes    no   1.0   no   0.0    0.0   Sometimes  Public_Transportation   Overweight_Level_I
# 358     Male   41    1.75   110.0                            yes   no   2.0   1.0   Sometimes    no   1.0   no   1.0    0.0  Frequently             Automobile      Obesity_Type_II
# 359   Female   33    1.56    48.0                            yes   no   2.0   3.0   Sometimes    no   2.0   no   1.0    0.0   Sometimes  Public_Transportation        Normal_Weight
# 361   Female   40    1.56    80.0                            yes  yes   2.0   1.0   Sometimes    no   2.0   no   2.0    0.0          no  Public_Transportation       Obesity_Type_I
# 362   Female   37    1.65    73.0                            yes   no   3.0   3.0   Sometimes    no   2.0   no   1.0    0.0   Sometimes             Automobile   Overweight_Level_I
# 366     Male   33    1.72    83.0                            yes  yes   2.0   1.0   Sometimes    no   2.0   no   3.0    0.0   Sometimes             Automobile  Overweight_Level_II
# 367   Female   40    1.58    63.0                             no  yes   2.0   3.0  Frequently    no   2.0   no   3.0    1.0   Sometimes  Public_Transportation   Overweight_Level_I
# 368   Female   37    1.68    83.0                            yes  yes   2.0   1.0   Sometimes    no   2.0   no   0.0    0.0          no             Automobile  Overweight_Level_II
# 375     Male   41     1.8    92.0                            yes  yes   2.0   1.0  Frequently    no   3.0   no   1.0    0.0   Sometimes             Automobile  Overweight_Level_II
# 376   Female   36    1.58    60.0                            yes   no   3.0   3.0   Sometimes    no   1.0   no   2.0    0.0   Sometimes             Automobile        Normal_Weight
# 382   Female   29     1.6    56.0                            yes   no   2.0   3.0  Frequently    no   1.0   no   0.0    1.0   Sometimes  Public_Transportation        Normal_Weight
# 387   Female   37     1.5    75.0                            yes  yes   2.0   3.0  Frequently    no   1.0   no   0.0    0.0   Sometimes              Motorbike       Obesity_Type_I
# 396   Female   38    1.55    59.0                            yes   no   3.0   3.0   Sometimes    no   1.0   no   2.0    1.0  Frequently             Automobile        Normal_Weight
# 404     Male   34    1.78    73.0                             no  yes   2.0   3.0   Sometimes    no   2.0   no   3.0    1.0   Sometimes             Automobile        Normal_Weight
# 406     Male   33    1.76    66.5                             no   no   2.0   3.0   Sometimes    no   2.0   no   3.0    1.0   Sometimes             Automobile        Normal_Weight
# 409   Female   33    1.55    55.0                            yes  yes   3.0   1.0   Sometimes    no   3.0   no   2.0    1.0   Sometimes  Public_Transportation        Normal_Weight
# 412     Male   33    1.85    85.0                             no  yes   2.0   3.0  Frequently    no   2.0   no   1.0    0.0   Sometimes             Automobile        Normal_Weight
# 413     Male   33    1.75    85.0                             no   no   2.0   3.0   Sometimes    no   2.0  yes   1.0    0.0   Sometimes  Public_Transportation  Overweight_Level_II
# 414     Male   33    1.83   113.0                            yes  yes   2.0   1.0      Always    no   2.0   no   1.0    2.0  Frequently             Automobile       Obesity_Type_I
# 416     Male   34    1.84    88.0                             no  yes   3.0   3.0   Sometimes    no   1.0  yes   2.0    0.0          no             Automobile   Overweight_Level_I
# 419     Male   29    1.62    89.0                            yes  yes   1.0   3.0   Sometimes    no   1.0   no   0.0    0.0   Sometimes  Public_Transportation       Obesity_Type_I
# 423     Male   33    1.85    93.0                            yes  yes   2.0   3.0   Sometimes    no   1.0   no   1.0    1.0   Sometimes                Walking  Overweight_Level_II
# 424     Male   33    1.74    76.0                             no   no   2.0   3.0   Sometimes    no   1.0   no   0.0    2.0   Sometimes                Walking   Overweight_Level_I
# 456   Female   33    1.59    60.0                             no  yes   3.0   1.0  Frequently    no   2.0   no   0.0    0.0          no  Public_Transportation        Normal_Weight
# 484   Female   36    1.65    80.0                            yes  yes   2.0   3.0   Sometimes    no   1.0   no   0.0    2.0          no             Automobile  Overweight_Level_II
# 492     Male   45     1.7    86.0                             no  yes   3.0   3.0  Frequently    no   1.0   no   0.0    0.0          no             Automobile  Overweight_Level_II
# 549   Female   30    1.61   49.52                            yes  yes  2.06   3.9  Frequently    no   2.0   no  0.82    0.0          no  Public_Transportation  Insufficient_Weight
# 550   Female   32    1.64   46.66                            yes  yes   3.0  3.11  Frequently    no  2.72   no  1.44    0.0          no  Public_Transportation  Insufficient_Weight
# 623   Female   35    1.69    50.0                            yes  yes  2.65   3.8  Frequently    no   1.6   no  0.17  0.097          no  Public_Transportation  Insufficient_Weight
# 751   Female   42    1.72   82.92                             no  yes  2.82  3.36   Sometimes    no  2.72   no   3.0  0.266   Sometimes             Automobile   Overweight_Level_I
# 756   Female   34    1.64    74.8                            yes   no   3.0  1.15   Sometimes    no  1.07   no  0.68    0.0   Sometimes             Automobile   Overweight_Level_I
# 759   Female   35    1.53    62.9                             no  yes   2.0  2.11   Sometimes    no  1.46   no   0.0  0.997   Sometimes             Automobile   Overweight_Level_I
# 760   Female   37    1.55   62.34                            yes  yes  2.39   3.0   Sometimes    no  2.95   no   0.0  0.369   Sometimes             Automobile   Overweight_Level_I
# 765   Female   31    1.63    68.8                            yes  yes  2.05   3.0   Sometimes    no  1.97   no  0.23    0.0   Sometimes             Automobile   Overweight_Level_I
# 777   Female   29    1.67    71.6                            yes  yes   2.0   3.0   Sometimes    no   1.7   no  1.68    0.0   Sometimes             Automobile   Overweight_Level_I
# 782   Female   33    1.72   72.75                            yes  yes   2.0   3.0   Sometimes    no   1.0   no   0.0  1.339   Sometimes             Automobile   Overweight_Level_I
# 787   Female   35    1.67   73.19                            yes   no   3.0  2.81   Sometimes    no  1.59   no  0.18    0.0   Sometimes             Automobile   Overweight_Level_I
# 789   Female   37    1.59   63.32                            yes  yes  2.37   3.0   Sometimes    no   2.0   no  2.89  0.481   Sometimes             Automobile   Overweight_Level_I
# 795     Male   30    1.82   87.67                             no  yes   3.0   3.0   Sometimes    no  1.17   no   2.0    0.0          no             Automobile   Overweight_Level_I
# 796   Female   32    1.66   73.64                            yes  yes   2.0   3.0   Sometimes    no   1.0   no   0.0  1.112   Sometimes             Automobile   Overweight_Level_I
# 803     Male   28    1.81   87.29                             no  yes   3.0   3.0   Sometimes    no  1.21   no   2.0    0.0          no             Automobile   Overweight_Level_I
# 813   Female   42    1.77   75.63                            yes  yes   3.0  2.95   Sometimes    no  2.11   no  0.38    0.0   Sometimes             Automobile   Overweight_Level_I
# 820   Female   33    1.67   74.81                            yes  yes  2.95   1.2   Sometimes    no   1.0   no   0.0  0.174   Sometimes             Automobile   Overweight_Level_I
# 821   Female   33    1.68   74.96                            yes  yes  2.29  1.56   Sometimes    no   1.0   no   0.0  0.388   Sometimes             Automobile   Overweight_Level_I
# 825   Female   37    1.51   63.18                            yes  yes  2.05  1.05   Sometimes    no   2.0   no  0.15  0.226   Sometimes             Automobile   Overweight_Level_I
# 826   Female   40    1.56   62.87                            yes  yes  2.95   3.0   Sometimes    no  2.43   no  0.12   0.36   Sometimes             Automobile   Overweight_Level_I
# 827   Female   39    1.55   63.01                            yes  yes  2.87   3.0   Sometimes    no  2.97   no  2.16  0.306   Sometimes             Automobile   Overweight_Level_I
# 835   Female   29    1.64   69.91                            yes  yes  2.37   3.0   Sometimes    no  1.93   no  1.58    0.0   Sometimes             Automobile   Overweight_Level_I
# 836   Female   31    1.69   71.93                            yes  yes  2.62   3.0   Sometimes    no  1.77   no  0.76  0.687   Sometimes             Automobile   Overweight_Level_I
# 856   Female   28     1.7   74.24                            yes  yes   2.0   3.0   Sometimes    no   2.0   no  1.72    0.0   Sometimes             Automobile   Overweight_Level_I
# 857     Male   29    1.77   82.05                            yes  yes  1.06  3.99   Sometimes    no  2.03   no  0.82  0.895   Sometimes  Public_Transportation   Overweight_Level_I
# 862   Female   30    1.65   73.58                            yes  yes   2.0   3.0   Sometimes    no   1.0   no   0.0  0.019   Sometimes             Automobile   Overweight_Level_I
# 863   Female   31    1.65   69.17                            yes  yes   2.0   3.0   Sometimes    no  1.13   no  0.06    0.0   Sometimes             Automobile   Overweight_Level_I
# 870   Female   35    1.65   73.92                            yes   no   3.0  2.73   Sometimes    no  1.62   no   0.9    0.0   Sometimes             Automobile   Overweight_Level_I
# 873   Female   40    1.57   62.21                            yes  yes  2.25   3.0   Sometimes    no  2.76   no  1.02  0.213   Sometimes             Automobile   Overweight_Level_I
# 882     Male   33    1.84   87.86                             no  yes  2.81  2.61   Sometimes    no  1.86   no   2.0  0.516          no             Automobile   Overweight_Level_I
# 1764    Male   31    1.84  125.97                            yes  yes  2.15   3.0   Sometimes   yes  1.49   no  0.88  0.528   Sometimes  Public_Transportation      Obesity_Type_II
# 1765    Male   31    1.83  124.95                            yes  yes  2.02   3.0   Sometimes    no  1.83   no   0.8  0.185   Sometimes  Public_Transportation      Obesity_Type_II
# 1766    Male   31    1.86  126.42                            yes  yes  2.93   3.0   Sometimes    no  1.51   no   0.9  1.015   Sometimes  Public_Transportation      Obesity_Type_II
# 1775    Male   37    1.76   118.4                            yes  yes  2.14  2.99   Sometimes    no  1.89   no  0.62    0.0   Sometimes             Automobile      Obesity_Type_II
# 1776    Male   38    1.75   119.2                            yes  yes   2.5  2.99   Sometimes    no  1.96   no  0.61  0.647   Sometimes             Automobile      Obesity_Type_II
# 1777    Male   39    1.77  117.79                            yes  yes  2.23  2.92   Sometimes    no  1.83   no  0.76    0.0   Sometimes             Automobile      Obesity_Type_II
# 1778    Male   38    1.77  118.13                            yes  yes  2.24  2.91   Sometimes    no   1.9   no  0.82    0.0   Sometimes             Automobile      Obesity_Type_II
# 1781    Male   34    1.71  103.28                            yes  yes  2.53  2.04   Sometimes    no   1.0   no  1.67  0.024          no  Public_Transportation      Obesity_Type_II
# 1782    Male   33     1.7  102.78                            yes  yes  2.74  2.02   Sometimes    no   1.0   no  1.98  0.056          no  Public_Transportation      Obesity_Type_II
# 1793    Male   31    1.65  101.14                            yes  yes  2.91  2.27   Sometimes    no   1.0   no  1.89  0.379          no  Public_Transportation      Obesity_Type_II
# 1794    Male   31    1.65  102.58                            yes  yes  2.92  2.14   Sometimes    no  1.18   no  0.96  0.636          no  Public_Transportation      Obesity_Type_II
#
# ===============
#
#   Gender  Age  Height  Weight family_history_with_overweight FAVC  FCVC  NCP       CAEC SMOKE  CH2O SCC  FAF  TUE        CALC                 MTRANS           NObeyesdad
# 2   Male   23     1.8    77.0                            yes   no   2.0  3.0  Sometimes    no   2.0  no  2.0  1.0  Frequently  Public_Transportation        Normal_Weight
# 3   Male   27     1.8    87.0                             no   no   3.0  3.0  Sometimes    no   2.0  no  2.0  0.0  Frequently                Walking   Overweight_Level_I
# 4   Male   22    1.78    89.8                             no   no   2.0  1.0  Sometimes    no   2.0  no  0.0  0.0   Sometimes  Public_Transportation  Overweight_Level_II
# 5   Male   29    1.62    53.0                             no  yes   2.0  3.0  Sometimes    no   2.0  no  0.0  0.0   Sometimes             Automobile        Normal_Weight
# 7   Male   22    1.64    53.0                             no   no   2.0  3.0  Sometimes    no   2.0  no  3.0  0.0   Sometimes  Public_Transportation        Normal_Weight
# Number of records where Gender starts with 'M': 1068
#
# ===============
#
# Total number of duplicate rows: 24
#
# ===============
#
# Age was Integer now It is : string
#
#    Gender Age  Height  Weight family_history_with_overweight FAVC  FCVC  NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS           NObeyesdad
# 0  Female  21    1.62    64.0                            yes   no   2.0  3.0  Sometimes    no   2.0   no  0.0  1.0          no  Public_Transportation        Normal_Weight
# 1  Female  21    1.52    56.0                            yes   no   3.0  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation        Normal_Weight
# 2    Male  23     1.8    77.0                            yes   no   2.0  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently  Public_Transportation        Normal_Weight
# 3    Male  27     1.8    87.0                             no   no   3.0  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently                Walking   Overweight_Level_I
# 4    Male  22    1.78    89.8                             no   no   2.0  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation  Overweight_Level_II
#
# ===============
#
#     Gender           NObeyesdad  Count
# 0   Female  Insufficient_Weight    173
# 1   Female        Normal_Weight    141
# 2   Female       Obesity_Type_I    156
# 3   Female      Obesity_Type_II      2
# 4   Female     Obesity_Type_III    323
# 5   Female   Overweight_Level_I    145
# 6   Female  Overweight_Level_II    103
# 7     Male  Insufficient_Weight     99
# 8     Male        Normal_Weight    146
# 9     Male       Obesity_Type_I    195
# 10    Male      Obesity_Type_II    295
# 11    Male     Obesity_Type_III      1
# 12    Male   Overweight_Level_I    145
# 13    Male  Overweight_Level_II    187
#
# ===============
#
# Missing values in each column:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64
#
# Total number of missing values in the dataset: 0
#
# ===============
#
# Missing values in each column before handling:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64
#
# Total missing values: 0
#
#
# No missing values found in the dataset.
#
# ===============
#
# Number of records in each Age bin:
#
# Age_Binned
# (13.953, 23.4]    1239
# (23.4, 32.8]       627
# (32.8, 42.2]       219
# (42.2, 51.6]        18
# (51.6, 61.0]         8
# Name: count, dtype: int64
#
# ===============
#
# Max weight row
#
#     Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 344   Male  18.0    1.87   173.0                            yes  yes   3.0
#
#      NCP        CAEC SMOKE  CH2O SCC  FAF  TUE       CALC  \
# 344  3.0  Frequently    no   2.0  no  2.0  1.0  Sometimes
#
#                     MTRANS        NObeyesdad      Age_Binned
# 344  Public_Transportation  Obesity_Type_III  (13.953, 23.4]
#
# ===============
#       Gender       Age    Height    Weight family_history_with_overweight  \
# 0     Female -0.521741 -0.874380 -0.862558                            yes
# 1     Female -0.521741 -1.945660 -1.168077                            yes
# 2       Male -0.207057  1.053924 -0.366089                            yes
# 3       Male  0.422312  1.053924  0.015809                             no
# 4       Male -0.364399  0.839668  0.122741                             no
# ...      ...       ...       ...       ...                            ...
# 2106  Female -0.521741  0.089772  1.711821                            yes
# 2107  Female -0.364399  0.518284  1.800804                            yes
# 2108  Female -0.207057  0.518284  1.798894                            yes
# 2109  Female -0.049714  0.411156  1.785909                            yes
# 2110  Female -0.049714  0.411156  1.790492                            yes
#
#      FAVC      FCVC       NCP       CAEC SMOKE  CH2O  SCC   FAF    TUE  \
# 0      no -0.784810  0.404102  Sometimes    no   2.0   no   0.0    1.0
# 1      no  1.088307  0.404102  Sometimes   yes   3.0  yes   3.0    0.0
# 2      no -0.784810  0.404102  Sometimes    no   2.0   no   2.0    1.0
# 3      no  1.088307  0.404102  Sometimes    no   2.0   no   2.0    0.0
# 4      no -0.784810 -2.166941  Sometimes    no   2.0   no   0.0    0.0
# ...   ...       ...       ...        ...   ...   ...  ...   ...    ...
# 2106  yes  1.088307  0.404102  Sometimes    no  1.73   no  1.68  0.906
# 2107  yes  1.088307  0.404102  Sometimes    no  2.01   no  1.34  0.599
# 2108  yes  1.088307  0.404102  Sometimes    no  2.05   no  1.41  0.646
# 2109  yes  1.088307  0.404102  Sometimes    no  2.85   no  1.14  0.586
# 2110  yes  1.088307  0.404102  Sometimes    no  2.86   no  1.03  0.714
#
#             CALC                 MTRANS           NObeyesdad      Age_Binned
# 0             no  Public_Transportation        Normal_Weight  (13.953, 23.4]
# 1      Sometimes  Public_Transportation        Normal_Weight  (13.953, 23.4]
# 2     Frequently  Public_Transportation        Normal_Weight  (13.953, 23.4]
# 3     Frequently                Walking   Overweight_Level_I    (23.4, 32.8]
# 4      Sometimes  Public_Transportation  Overweight_Level_II  (13.953, 23.4]
# ...          ...                    ...                  ...             ...
# 2106   Sometimes  Public_Transportation     Obesity_Type_III  (13.953, 23.4]
# 2107   Sometimes  Public_Transportation     Obesity_Type_III  (13.953, 23.4]
# 2108   Sometimes  Public_Transportation     Obesity_Type_III  (13.953, 23.4]
# 2109   Sometimes  Public_Transportation     Obesity_Type_III    (23.4, 32.8]
# 2110   Sometimes  Public_Transportation     Obesity_Type_III    (23.4, 32.8]
#
# [2111 rows x 18 columns]
# pca operation
# PCA Result:
#            PC1       PC2
# 0    -1.529383 -0.143360
# 1    -2.065816 -0.118542
# 2    -0.648907 -0.057469
# 3     0.036152  0.179130
# 4     0.206651 -0.164197
# ...        ...       ...
# 2106  2.999229 -0.383131
# 2107  3.159374 -0.323486
# 2108  3.159529 -0.256522
# 2109  3.140500 -0.188363
# 2110  3.148560 -0.188894
#
# [2111 rows x 2 columns]
# ===============
# ===============

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from pandas import read_csv
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
dataset=pd.read_csv('Obesity.csv')
dataset = dataset.convert_dtypes()


#Practical Analytical Questions

#a) Use Python to calculate and display the correlation matrix, and identify potential features relevant for classification.
# Select only numeric columns
numeric_dataset = dataset.select_dtypes(include=[float, int])

# Compute the correlation matrix
correlation_matrix = numeric_dataset.corr()
print(correlation_matrix)

# Select the correlation of 'Age' with other features
target_correlation = correlation_matrix["NCP"]

# Select features with correlation greater than 0.1
relevant_features = target_correlation[abs(target_correlation) > 0.1]
print("\nFeatures relevant for Classification:")
print(relevant_features)


print("\n===============\n")


#b) Use Python to find the class distribution of a selected categorical feature and analyze the results.

# Display the class distribution of the 'NObeyesdad' feature
class_distribution = dataset["NObeyesdad"].value_counts()

print("Class Distribution of 'NObeyesdad':")
print(class_distribution)


print("\n===============\n")


#c)Apply Python techniques to create new features from existing ones (feature engineering) and explain the significance of the new features.

# Create a new feature 'BMI' by calculating Body Mass Index using

# the formula: BMI = Weight (kg) / (Height (m) ^ 2)
dataset["Height"] = dataset["Height"] / 100
dataset["BMI"] = dataset["Weight"] / (dataset["Height"] ** 2)
print("New dataset with BMI feature:")
print(dataset.head(12).to_string())
# Out:
#              Age    Height    Weight      FCVC       NCP      CH2O       FAF  \
# Age     1.000000 -0.025775  0.203451  0.017020 -0.043951 -0.045583 -0.145081
# Height -0.025775  1.000000  0.462264 -0.038580  0.243387  0.213469  0.295354
# Weight  0.203451  0.462264  1.000000  0.216268  0.107413  0.200543 -0.051355
# FCVC    0.017020 -0.038580  0.216268  1.000000  0.042045  0.068401  0.019936
# NCP    -0.043951  0.243387  0.107413  0.042045  1.000000  0.056936  0.129519
# CH2O   -0.045583  0.213469  0.200543  0.068401  0.056936  1.000000  0.167181
# FAF    -0.145081  0.295354 -0.051355  0.019936  0.129519  0.167181  1.000000
# TUE    -0.296609  0.051583 -0.071571 -0.101221  0.036404  0.011924  0.058586
#
#              TUE
# Age    -0.296609
# Height  0.051583
# Weight -0.071571
# FCVC   -0.101221
# NCP     0.036404
# CH2O    0.011924
# FAF     0.058586
# TUE     1.000000
#
# Features relevant for Classification:
# Height    0.243387
# Weight    0.107413
# NCP       1.000000
# FAF       0.129519
# Name: NCP, dtype: float64
#
# ===============
#
# Class Distribution of 'NObeyesdad':
# NObeyesdad
# Obesity_Type_I         351
# Obesity_Type_III       324
# Obesity_Type_II        297
# Overweight_Level_I     290
# Overweight_Level_II    290
# Normal_Weight          287
# Insufficient_Weight    272
# Name: count, dtype: Int64
#
# ===============
#
# New dataset with BMI feature:
#     Gender  Age  Height  Weight family_history_with_overweight FAVC  FCVC  NCP        CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS           NObeyesdad            BMI
# 0   Female   21  0.0162    64.0                            yes   no   2.0  3.0   Sometimes    no   2.0   no  0.0  1.0          no  Public_Transportation        Normal_Weight  243865.264441
# 1   Female   21  0.0152    56.0                            yes   no   3.0  3.0   Sometimes   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation        Normal_Weight  242382.271468
# 2     Male   23   0.018    77.0                            yes   no   2.0  3.0   Sometimes    no   2.0   no  2.0  1.0  Frequently  Public_Transportation        Normal_Weight  237654.320988
# 3     Male   27   0.018    87.0                             no   no   3.0  3.0   Sometimes    no   2.0   no  2.0  0.0  Frequently                Walking   Overweight_Level_I  268518.518519
# 4     Male   22  0.0178    89.8                             no   no   2.0  1.0   Sometimes    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation  Overweight_Level_II  283423.810125
# 5     Male   29  0.0162    53.0                             no  yes   2.0  3.0   Sometimes    no   2.0   no  0.0  0.0   Sometimes             Automobile        Normal_Weight  201950.922116
# 6   Female   23   0.015    55.0                            yes  yes   3.0  3.0   Sometimes    no   2.0   no  1.0  0.0   Sometimes              Motorbike        Normal_Weight  244444.444444
# 7     Male   22  0.0164    53.0                             no   no   2.0  3.0   Sometimes    no   2.0   no  3.0  0.0   Sometimes  Public_Transportation        Normal_Weight  197055.324212
# 8     Male   24  0.0178    64.0                            yes  yes   3.0  3.0   Sometimes    no   2.0   no  1.0  1.0  Frequently  Public_Transportation        Normal_Weight  201994.697639
# 9     Male   22  0.0172    68.0                            yes  yes   2.0  3.0   Sometimes    no   2.0   no  1.0  1.0          no  Public_Transportation        Normal_Weight  229853.975122
# 10    Male   26  0.0185   105.0                            yes  yes   3.0  3.0  Frequently    no   3.0   no  2.0  2.0   Sometimes  Public_Transportation       Obesity_Type_I  306793.279766
# 11  Female   21  0.0172    80.0                            yes  yes   2.0  3.0  Frequently    no   2.0  yes  2.0  1.0   Sometimes  Public_Transportation  Overweight_Level_II   270416.44132
